# %%
from ipywidgets import Output, HBox
from widgets.slider import Slider

# %%
out = Output()
with out:
    out.clear_output(wait=True)
    s = Slider()

# %%
box = HBox([out])
box

# %%
s.value
# Out:
# 59
