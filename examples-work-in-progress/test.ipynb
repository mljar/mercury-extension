# %%
from widgets.slider import Slider
from widgets.progressbar import Progressbar

# %% [markdown]
# # Ciao Ola!

# %%
p = Progressbar()
# Out:
# HTML(value='\n    <style>\n      .mljar-progress {\n        width: 100%;\n        display: flex;\n        flex…
# _ProgressVBox(children=(HBox(children=(HTML(value=''), HBox(children=(HTML(value='0%'),), layout=Layout(flex='…

# %%
s = Slider(value=5, max=5)
# Out:
# SliderWidget(max=5, value=5)

# %%
import time
for i in range(s.value):
    p.set(s.value)
    time.sleep(1)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 10, 27, 11, 16, 55, 103418)
