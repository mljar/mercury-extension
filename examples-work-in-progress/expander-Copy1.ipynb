# %%
from widgets import Expander
from widgets.slider import Slider

# %%
out = Expander(label="Training details", expanded=False, key="train-expander", position="inline")

with out:
    import time, sys
    print("Fold 1/5: AUC=0.842")
    print("Fold 2/5: AUC=0.851")
# Out:
# HTML(value='<style>\n      .mljar-expander-box { width:100%; border:1px solid #cccccc;\n        border-radius:…
# VBox(children=(_ExpanderHeaderWidget(label='Training details'), Box(children=(Output(layout=Layout(width='100%…

# %%
with out:
    import time, sys
    print("Fold 1/5: AUC=0.842")
    print("Fold 2/5: AUC=0.851")

# %%
with out:
    s = Slider()

# %%
s.value
# Out:
# 84
