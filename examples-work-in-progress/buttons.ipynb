# %%
from widgets.button import Button
from widgets.manager import WidgetsManager

# %%
b = Button(label="test me")
# Out:
# ButtonWidget(label='test me')

# %%
from widgets.slider import Slider
s = Slider(position="bottom")
# Out:
# SliderWidget(cell_id='a6d5f899-74f8-4a70-9324-c7e6ca905d9b', position='bottom')

# %%
from widgets.checkbox import Checkbox

# %%
cb = Checkbox(label="Auto-refresh", appearance="box", disabled=True, hidden=True)      # toggle switch
# Out:
# CheckboxWidget(appearance='box', cell_id='27ccd6fa-1891-478b-ac91-88c90f356acf', disabled=True, label='Auto-re…

# %%
cb2 = Checkbox(label="Auto-refresh", appearance="toggle")
# Out:
# CheckboxWidget(cell_id='1c544439-0455-4756-b4fd-15ee1e351db5', label='Auto-refresh')

# %%
if cb.value:
    print("It's ON!")

# %%
import os


class StopExecution(Exception):
    def _render_traceback_(self):
        pass


def Stop():
    raise StopExecution()

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-10-27 13:03:44.713067

# %%
b.value
# Out:
# True

# %%
b.n_clicks
# Out:
# 11

# %%
cb2.value
# Out:
# False
