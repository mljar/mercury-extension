# %%
from widgets.progressbar import Progressbar

# %%
# Determinate
ph = Progressbar(label="Training model…", value=0, max=100, key="train-progress")
for i in range(0, 101, 10):
    ph.set(i)
# Out:
# HTML(value='\n    <style>\n      .mljar-progress {\n        width: 100%;\n        display: flex;\n        flex…
# _ProgressVBox(children=(HBox(children=(HTML(value='Training model…'), HBox(children=(HTML(value='0%'),), layou…

# %%
from widgets.text import TextInput

# %%
t = TextInput(position="bottom")
# Out:
# TextInputWidget(cell_id='ca54a6f2-00d9-48f2-8498-f360d925b949', position='bottom', value='azzzzzzzzzzzzzzzzzzz…

# %%
t2 = TextInput(position="bottom")
# Out:
# TextInputWidget(position='bottom')

# %%
t.value
# Out:
# 'azzzzzzzzzzzzzzzzzzzzzzzzzzz'

# %%
ph.set(12)

# %%
# Indeterminate
spinner = Progressbar(label="Fetching data…", indeterminate=True, show_percent=True, key="fetch-progress", position="sidebar")
# ... later:
# Out:
# HTML(value='\n    <style>\n      .mljar-progress {\n        width: 100%;\n        display: flex;\n        flex…
# _ProgressVBox(children=(HBox(children=(HTML(value='Done!'), HBox(children=(HTML(value='20%'),), layout=Layout(…

# %%
spinner.set_indeterminate(False)

# %%
spinner.set(20)

# %%
spinner.set_label("Done!")
