# %%
import pandas as pd
from mercury.table import Table

kraje = ["Polska", "Niemcy", "Francja"]

df = pd.DataFrame({
    "Kraj": [kraje[i % 3] for i in range(100)],
    "Rok": [2020 + (i % 10) for i in range(100)],
    "PKB": [500 + (i * 25) for i in range(100)],
})
t = Table(df, page_size=30)
t
# Out:
#     <style>
#       /* hide default AG Grid sort icons */
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-header-icon,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-icon-asc,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-icon-desc,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-icon-sort-ascending,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-icon-sort-descending,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-paging-button .ag-icon,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-paging-panel .ag-icon,
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-paging-button[ref="btFirst"],
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-paging-button[ref="btLast"] {
#         display: none !important;
#       }
#
#       #aggrid_3b31559353df45af8add53e16a6ccd23 .ag-paging-button::after {
#         font-size: 14px;
#         padding: 0 6px;
#         cursor: pointer;
#         opacity: 0.8;
#         color: #bbb;
# ...
