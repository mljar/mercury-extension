# %%
import pandas as pd
from mercury.table import Table

df = pd.DataFrame({
    "Kraj": ["Polska", "Niemcy", "Francja"],
    "Rok": [2022, 2023, 2024],
        "PKB": [680, 4200, 3100],
})
t = Table(df)
t
# Out:
#     <style>
#       /* hide default AG Grid sort icons */
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-header-icon,
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-icon-asc,
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-icon-desc,
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-icon-sort-ascending,
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-icon-sort-descending {
#         display: none !important;
#       }
#
#       /* custom sort arrows */
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-header-cell-label::after {
#         content: "";
#         margin-left: 4px;
#         font-size: 0.7em;
#       }
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-header-cell-sorted-asc .ag-header-cell-label::after {
#         content: "▲";
#       }
#       #aggrid_76a85d70b2f84e5990415139eda6d193 .ag-header-cell-sorted-desc .ag-header-cell-label::after {
#         content: "▼";
#       }
#     </style>
#
#     <!-- table container -->
# ...

# %%
Table(df)
# Out:
#     <style>
#       /* hide default AG Grid sort icons */
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-header-icon,
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-icon-asc,
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-icon-desc,
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-icon-sort-ascending,
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-icon-sort-descending {
#         display: none !important;
#       }
#
#       /* custom sort arrows */
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-header-cell-label::after {
#         content: "";
#         margin-left: 4px;
#         font-size: 0.7em;
#       }
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-header-cell-sorted-asc .ag-header-cell-label::after {
#         content: "▲";
#       }
#       #aggrid_7a29ce58c9574dbdb597daa417996b00 .ag-header-cell-sorted-desc .ag-header-cell-label::after {
#         content: "▼";
#       }
#     </style>
#
#     <!-- table container -->
# ...
