# %%
import yfinance as yf
import pandas as pd
import numpy as np
import altair as alt
from mercury import MultiSelect, Indicator, Markdown, Table

# %%
stocks_list = ["AAPL", "MSFT", "GOOG", "AMZN", "TSLA", "NVDA"]
stocks = MultiSelect(label="Stocks", value=stocks_list, choices=stocks_list, position="inline")
# Out:
# () {'label': 'Stocks', 'value': ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'], 'choices': ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'], 'position': 'inline'}
# MultiSelectWidget(choices=['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'], label='Stocks', position='inline', value=['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'])

# %%
stocks_list
# Out:
# ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA']

# %%
stocks2 = MultiSelect(label="Stocks", value=stocks_list, choices=stocks_list, position="inline")
# Out:
# () {'label': 'Stocks', 'value': ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'], 'choices': ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'], 'position': 'inline'}
# MultiSelectWidget(choices=['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'], label='Stocks', position='inline', value=['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA'])

# %% [markdown]
# # Stocks dashboard
#
# Your personal dashboard for watching markets move. Get instant insights into price swings and performance momentum.

# %%
Markdown("""
### 📝 What This Dashboard Does

✅ Select stocks you want to track using a Mercury MultiSelect widget

📥 Download recent price history automatically for the selected tickers

💳 Show indicator cards (price + % change) for each stock

📈 Display a line chart comparing how prices changed over time

Everything updates automatically when you change the selected stocks.
""", position="sidebar")
# Out:
# MarkdownWidget(value='<h3>📝 What This Dashboard Does</h3>\n<p>✅ Select stocks you want to track using a Mercur…

# %%
# List of 5 stock tickers
tickers = stocks.value

# Download last 5 days of data
data = yf.download(
    tickers,
    period="300d",
    auto_adjust=False,
    progress=False
)["Close"]

# Print the closing prices
# data

# %%
indicators = []
for ticker in tickers:
    indicators += [Indicator(label=ticker, value=f"{np.round(data[ticker].iloc[-1],2)}$", delta=np.round((data[ticker].iloc[-1]-data[ticker].iloc[0])/data[tickers[0]].iloc[0]*100,1))]

# %%
Indicator(indicators)
# Out:
#         <style scoped>
#         .mljar-indicator-row {
#             width: 100%;
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             gap: 12px;
#             justify-content: flex-start;
#             align-items: stretch;
#             box-sizing: border-box;
#             padding: 5px;
#         }
#         @media (max-width: 800px) {
#             .mljar-indicator-row {
#                 flex-direction: column;
#             }
#             .mljar-indicator-card {
#                 flex: 1 1 100%;
#                 max-width: 100% !important;
#                 min-width: 0;
#             }
#         }
#         .mljar-indicator-card {
#             flex: 0 1 180px;
#             background: var(--bg, #fff);
#             border: 1px solid var(--border, #ebebeb);
#             border-radius: 10px;
#             padding: 20px 18px 14px 18px;
#             text-align: center;
#             min-width: 150px;
#             max-width: 210px !important;
#             box-shadow: 0 2px 8px rgba(0,0,0,0.04);
#         }
#         .mljar-indicator-title {
#             font-size: 1.25em !important;
#             color: var(--label, #555);
#             margin-bottom: 8px;
#             font-family: 'Inter', 'Segoe UI', Arial, sans-serif !important;
#         }
#         .mljar-indicator-value {
#             font-size: 2.3em;
#             color: var(--value, #222);
#             font-family: 'Menlo', 'Consolas', monospace;
#
#             margin-bottom: 10px;
#             letter-spacing: 1px;
#         }
#         .mljar-indicator-delta {
#             display: inline-block;
#             padding: 0.24em 1em 0.24em 1em;
#             font-size: 0.95em;
#             border-radius: 2em;
#             margin-bottom: 4px;
#             font-family: 'Menlo', monospace;
#             font-weight: bold;
#         }
#         .mljar-indicator-delta.up {
#             background: var(--bg-green, rgba(0,178,117,0.12));
#             color: var(--green, #00B275);
#         }
#         .mljar-indicator-delta.down {
#             background: var(--bg-red, rgba(255,99,132,0.13));
#             color: var(--red, #FF6384);
#         }
#         </style>
#         <div class='mljar-indicator-row'>
# <div class="mljar-indicator-card"
#      style="--bg:#fff;--border:#ebebeb;--value:#222;--label:#555;--green:#00B275;--bg-green:rgba(0, 178, 117, 0.12);--red:#FF6384;--bg-red:rgba(255, 99, 132, 0.13)">
#     <div class='mljar-indicator-title'>AMZN</div>
#     <div class='mljar-indicator-value'>237.58$</div>
#     <div class='mljar-indicator-delta up'><span style='font-size:1.15em'>&#8593;</span> 33.6%</div>
# </div>
#
# <div class="mljar-indicator-card"
#      style="--bg:#fff;--border:#ebebeb;--value:#222;--label:#555;--green:#00B275;--bg-green:rgba(0, 178, 117, 0.12);--red:#FF6384;--bg-red:rgba(255, 99, 132, 0.13)">
#     <div class='mljar-indicator-title'>MSFT</div>
#     <div class='mljar-indicator-value'>503.29$</div>
#     <div class='mljar-indicator-delta up'><span style='font-size:1.15em'>&#8593;</span> 53.3%</div>
# </div>
# </div>

# %%
df = data.copy()
df = df.reset_index().rename(columns={"index": "Date"})

# melt into long format
df_melt = df.melt("Date", var_name="Ticker", value_name="Price")

# altair chart
chart = (
    alt.Chart(df_melt)
    .mark_line()
    .encode(
        x="Date:T",
        y="Price:Q",
        color="Ticker:N",
        tooltip=["Date:T", "Ticker:N", "Price:Q"],
    )
    .properties(
        width="container",   # 👈 full width
        height=400
    )
    .interactive()
)

chart
# Out:
# alt.Chart(...)
